# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/textS.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/textS.zip
#   inflating: /content/params.yaml
#   inflating: /content/requirements.txt
#    creating: /content/config/
#   inflating: /content/config/config.yaml
#    creating: /content/src/
#    creating: /content/src/textSummarizer/
#    creating: /content/src/textSummarizer/components/
#   inflating: /content/src/textSummarizer/components/data_ingestion.py
#   inflating: /content/src/textSummarizer/components/data_transformation.py
#   inflating: /content/src/textSummarizer/components/data_validation.py
#   inflating: /content/src/textSummarizer/components/model_evaluation.py
#   inflating: /content/src/textSummarizer/components/model_trainer.py
#   inflating: /content/src/textSummarizer/components/__init__.py
#    creating: /content/src/textSummarizer/components/__pycache__/
#   inflating: /content/src/textSummarizer/components/__pycache__/data_ingestion.cpython-311.pyc
# ...

# %%
# !mkdir -p artifacts/data_transformation
# !mkdir -p artifacts/model_trainer
# !mkdir -p artifacts/model_evaluation

# %%
# !unzip /content/drive/MyDrive/model_artifacts.zip -d /content/
# Out:
# Archive:  /content/drive/MyDrive/model_artifacts.zip
#    creating: /content/artifacts/model_trainer/pegasus-samsum-model/
#   inflating: /content/artifacts/model_trainer/pegasus-samsum-model/generation_config.json
#   inflating: /content/artifacts/model_trainer/pegasus-samsum-model/config.json
#   inflating: /content/artifacts/model_trainer/pegasus-samsum-model/model.safetensors
#    creating: /content/artifacts/model_trainer/tokenizer/
#   inflating: /content/artifacts/model_trainer/tokenizer/tokenizer.json
#   inflating: /content/artifacts/model_trainer/tokenizer/tokenizer_config.json

# %%
# !cp -r "/content/drive/MyDrive/samsum_dataset" artifacts/data_transformation/

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.6/134.6 kB 16.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.0/140.0 kB 18.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 kB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 495.6/495.6 kB 44.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 90.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.6/100.6 kB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.3/144.3 kB 8.5 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade ensure
# Out:
# ...
#   Attempting uninstall: ensure
#     Found existing installation: ensure 1.0.2
#     Uninstalling ensure-1.0.2:
#       Successfully uninstalled ensure-1.0.2
# ...

# %%
# !python main.py
# Out:
# [2026-06-29 14:11:06,122: INFO: utils: NumExpr defaulting to 2 threads.]
# [2026-06-29 14:11:07,225: INFO: config: TensorFlow version 2.20.0 available.]
# [2026-06-29 14:11:07,226: INFO: config: JAX version 0.7.2 available.]
# [2026-06-29 14:11:11,451: INFO: main: >>>>>> Model Evaluation Stage Started <<<<<<]
# [2026-06-29 14:11:11,454: INFO: common: yaml file: config/config.yaml loaded successfully]
# [2026-06-29 14:11:11,455: INFO: common: yaml file: params.yaml loaded successfully]
# [2026-06-29 14:11:11,456: INFO: common: Created directory at: artifacts]
# [2026-06-29 14:11:11,456: INFO: common: Created directory at: artifacts/model_evaluation]
# [2026-06-29 14:11:11,456: INFO: model_evaluation: Model Evaluation stage initiated. Target environment device: cuda]
# [2026-06-29 14:11:11,456: INFO: model_evaluation: Loading local tokenizer configuration from: artifacts/model_trainer/tokenizer]
# ...
