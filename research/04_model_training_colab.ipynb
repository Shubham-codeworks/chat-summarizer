# %%
from google.colab import drive
import os

drive.mount('/content/drive')
# !rm -rf /content/text_summarizer
# !unzip /content/drive/MyDrive/text_summarizer.zip -d /content/text_summarizer
# %cd /content/text_summarizer
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Archive:  /content/drive/MyDrive/text_summarizer.zip
#    creating: /content/text_summarizer/config/
#   inflating: /content/text_summarizer/config/config.yaml
#    creating: /content/text_summarizer/research/
#   inflating: /content/text_summarizer/research/01_data_ingestion.ipynb
#   inflating: /content/text_summarizer/research/02_data_validation.ipynb
#   inflating: /content/text_summarizer/research/03_data_transformation.ipynb
#   inflating: /content/text_summarizer/research/04_model_trainer.ipynb
#    creating: /content/text_summarizer/research/logs/
#   inflating: /content/text_summarizer/research/logs/running_logs.log
#   inflating: /content/text_summarizer/research/text_summarization.ipynb
#   inflating: /content/text_summarizer/research/trials.ipynb
#    creating: /content/text_summarizer/src/
# ...

# %%
# Upgrade setup tools
# !pip install --upgrade setuptools wheel

# %%
# Install everything EXCEPT the local package
# !grep -v "^\s*-e" requirements.txt | grep -v "^\s*\." | pip install -r /dev/stdin

# Install local package structure
# !python setup.py develop
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.6/134.6 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.0/140.0 kB 17.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 495.6/495.6 kB 27.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 105.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.6/100.6 kB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.3/144.3 kB 16.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.1/90.1 kB 11.6 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade transformers accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 118.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.12.0
#     Uninstalling transformers-5.12.0:
#       Successfully uninstalled transformers-5.12.0
# ...

# %%
# !pip install --upgrade ensure
# Out:
# ...
#   Attempting uninstall: ensure
#     Found existing installation: ensure 1.0.2
#     Uninstalling ensure-1.0.2:
#       Successfully uninstalled ensure-1.0.2
# ...

# %%
# !python main.py
# Out:
# [2026-06-23 11:10:21,175: INFO: utils: NumExpr defaulting to 2 threads.]
# [2026-06-23 11:10:21,912: INFO: config: TensorFlow version 2.20.0 available.]
# [2026-06-23 11:10:21,913: INFO: config: JAX version 0.7.2 available.]
# [2026-06-23 11:10:23,015: INFO: main: >>>>> Data Ingestion Stage started <<<<<]
# [2026-06-23 11:10:23,017: INFO: common: yaml file: config/config.yaml loaded successfully]
# [2026-06-23 11:10:23,018: INFO: common: yaml file: params.yaml loaded successfully]
# [2026-06-23 11:10:23,018: INFO: common: Created directory at: artifacts]
# [2026-06-23 11:10:23,018: INFO: common: Created directory at: artifacts/data_ingestion]
# [2026-06-23 11:10:23,019: INFO: data_ingestion: File already exists of size ~ 2875 KB]
# [2026-06-23 11:10:23,268: INFO: data_ingestion: Extracted archieve content to artifacts/data_ingestion]
# [2026-06-23 11:10:23,268: INFO: main: >>>>> Data Ingestion Stage completed <<<<<
# ]
# ...

# %%
# !ls artifacts/model_trainer
# Out:
# checkpoint-921	pegasus-samsum-model  tokenizer

# %%
# !zip -r model_artifacts.zip artifacts/model_trainer/pegasus-samsum-model artifacts/model_trainer/tokenizer
# Out:
#   adding: artifacts/model_trainer/pegasus-samsum-model/ (stored 0%)
#   adding: artifacts/model_trainer/pegasus-samsum-model/generation_config.json (deflated 41%)
#   adding: artifacts/model_trainer/pegasus-samsum-model/config.json (deflated 61%)
#   adding: artifacts/model_trainer/pegasus-samsum-model/model.safetensors (deflated 7%)
#   adding: artifacts/model_trainer/tokenizer/ (stored 0%)
#   adding: artifacts/model_trainer/tokenizer/tokenizer.json (deflated 78%)
#   adding: artifacts/model_trainer/tokenizer/tokenizer_config.json (deflated 78%)

# %%
# !cp model_artifacts.zip /content/drive/MyDrive/
